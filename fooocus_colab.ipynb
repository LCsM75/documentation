# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 49.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.19.0
#     Uninstalling pygit2-1.19.0:
#       Successfully uninstalled pygit2-1.19.0
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6735, done.
# remote: Total 6735 (delta 0), reused 0 (delta 0), pack-reused 6735 (from 1)
# Receiving objects: 100% (6735/6735), 33.35 MiB | 37.57 MiB/s, done.
# Resolving deltas: 100% (3849/3849), done.
# /content/Fooocus

# %%
from google.colab import drive
drive.mount('/content/drive')
# Példa parancs (ezt írd át a te mappádra):
# !cp "/content/drive/MyDrive/Loras/Lilly_v2/output/Lilly_v2-10.safetensors" "/content/Fooocus/models/loras/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !wget -O /content/Fooocus/models/checkpoints/realvisxlV50_v50Bakedvae.safetensors "https://civitai.com/api/download/models/344487"
# Out:
# --2025-12-06 08:16:03--  https://civitai.com/api/download/models/344487
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::6814:26db, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/26957/realvisxlV40.2z1a.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22realvisxlV50_v40Bakedvae.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20251206/us-east-1/s3/aws4_request&X-Amz-Date=20251206T081603Z&X-Amz-SignedHeaders=host&X-Amz-Signature=d98716a54c3f4a5d381e97bb9230e3014fae6f8158acb2fe53484bbc4ff31115 [following]
# ...

# %%
# !wget -O /content/Fooocus/models/checkpoints/gonzalomoZpop_v10.safetensors "https://civitai.com/api/download/models/2468753?type=Model&format=SafeTensor&size=pruned&fp=fp16&token=8ad33f3e96d45577e13703a1cf088a10"
# Out:
# --2025-12-06 08:21:24--  https://civitai.com/api/download/models/2468753?type=Model&format=SafeTensor&size=pruned&fp=fp16&token=8ad33f3e96d45577e13703a1cf088a10
# Resolving civitai.com (civitai.com)... 172.66.152.186, 104.20.38.219, 2606:4700:10::6814:26db, ...
# Connecting to civitai.com (civitai.com)|172.66.152.186|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/7026904/gonzalomozpopV10.fL4p.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22gonzalomoZpop_v10.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20251206/us-east-1/s3/aws4_request&X-Amz-Date=20251206T082124Z&X-Amz-SignedHeaders=host&X-Amz-Signature=e88d10b1d07868879489cc38ccbbdf34ef78e51922806adc37baac57ebe202a0 [following]
# ...

# %%
# !python entry_with_update.py --share --always-high-vram
# Out:
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Total VRAM 15095 MB, total RAM 12976 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7865
# Running on public URL: https://1bf15c06ac38f64400.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# ...
